# %% [markdown]
# # julia plot test

# %%
@time using Plots
# Out:
#   0.000505 seconds (236 allocations: 12.516 KiB)

# %%
@time x = rand(10,3)
# Out:
#   0.000017 seconds (5 allocations: 496 bytes)
# 10×3 Array{Float64,2}:
#  0.456254    0.968847   0.495452
#  0.114051    0.194556   0.317276
#  0.995669    0.365518   0.262609
#  0.152027    0.487558   0.83419
#  0.0275059   0.831942   0.11459
#  0.594548    0.662411   0.50771
#  0.466003    0.122677   0.647533
#  0.145357    0.0196608  0.587649
#  0.00870854  0.656579   0.42715
#  0.94837     0.0566853  0.936071

# %%
@time plot(x)
# Out:
#   0.007689 seconds (4.89 k allocations: 283.875 KiB)
